# %% [markdown]
# ## Random Forest Regressor

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
import pickle

# %% [markdown]
# #### Lectura de train y test

# %%
# lo voy a traer directamente del dataset procesado, para dividirlo en X train y test
# e y train y test

df = pd.read_csv(r'C:\Users\plaza\Desktop\Documentos_Clase\ONLINE_DS_THEBRIDGE_Alejandro_Plaza\Proyecto_ML\data\processed\dfdefinitivo.csv')
df.head()
# Out:
#    Hours_Studied  Attendance  Previous_Scores  Tutoring_Sessions  PI_High  \
# 0              0           4                7                  1        0
# 1              1          27               13                  0        0
# 2              1          25                6                  1        1
# 3              1          13               11                  1        0
# 4              2          23                1                  1        0
#
#    PI_Low  AtR_High  AtR_Low  Exam_Score
# 0       0         0        1           9
# 1       1         0        0           3
# 2       0         0        0           9
# 3       0         0        0           2
# 4       1         1        0           7

# %%
df[df['Exam_Score'] < 50]#['Exam_Score'].value_counts().sort_values(ascending = False)
# Out:
#       Hours_Studied  Attendance  Previous_Scores  Tutoring_Sessions  \
# 6607              9          39               35                  1
# 6608             12          36               53                  5
# 6609              5          55               32                  1
# 6610             12          60               35                  0
# 6611             13          59               40                  0
# ...             ...         ...              ...                ...
# 9602              0          51               18                  2
# 9603             10          47               34                  1
# 9604              4          51               48                  1
# 9605              6          54               22                  4
# 9606             12          39               35                  1
#
#       Exam_Score  PI_High  PI_Low  AtR_High  AtR_Low
# 6607          21        1       0         1        0
# 6608          32        0       0         0        1
# 6609          22        0       1         0        1
# 6610          26        0       0         0        0
# 6611          24        0       0         1        0
# ...          ...      ...     ...       ...      ...
# 9602          18        0       0         1        0
# 9603          22        0       1         1        0
# 9604          18        0       1         0        0
# 9605          21        1       0         0        1
# 9606          18        0       0         0        0
#
# [2998 rows x 9 columns]

# %% [markdown]
# #### Dividimos en train y test

# %%
X = df.drop(columns = 'Exam_Score')
y = df['Exam_Score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 30)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8000, 8)
# (2000, 8)
# (8000,)
# (2000,)

# %%
param = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %% [markdown]
# #### Entrenamos al modelo

# %%
grid_search = GridSearchCV(estimator=RandomForestRegressor(random_state=42),
                    param_grid = param,
                    cv = 5,
                    scoring = 'r2',  
                    verbose = 1,
                    n_jobs = -1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='r2', verbose=1)

# %%
print("Best parameters:", grid_search.best_params_)
print("Best (negative) MAE:", grid_search.best_score_)
print("Best MAE:", -grid_search.best_score_)
# Out:
# Best parameters: {'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Best (negative) MAE: 0.9801299942903974
# Best MAE: -0.9801299942903974

# %% [markdown]
# #### Hacemos predicciones con los mejores parámetros y vemos los resultados

# %%
h_rf = grid_search.best_estimator_
h_rf.fit(X_train, y_train)

y_pred = h_rf.predict(X_test)

print("MAE", mean_absolute_error(y_test, y_pred))
print("MSE", mean_squared_error(y_test, y_pred))
print("RMSE", mean_squared_error(y_test, y_pred) ** (1/2))
print("MAPE", mean_absolute_percentage_error(y_test, y_pred))
print("r2_score", r2_score(y_test, y_pred))
# Out:
# MAE 3.279756627865798
# MSE 16.412523882646422
# RMSE 4.051237327366347
# MAPE 298729025606111.0
# r2_score 0.9802217277832995

# %%
sns.scatterplot(x = y_test, y = y_pred)
# Out:
# <Axes: xlabel='Exam_Score'>

# %% [markdown]
# Tras comprobar qué variables ha usado más, nos damos cuenta, que han sido las notas anteriores

# %%
feature_names = ['Hours_Studied', 'Attendance', 'Previous_Scores', 'Tutoring_Sessions',
       'PI_High', 'PI_Low', 'AtR_High', 'AtR_Low']
importances = h_rf.feature_importances_

# %%
for feature, importance in zip(feature_names, importances):
    print(f"{feature}: {importance:.4f}")
# Out:
# Hours_Studied: 0.0073
# Attendance: 0.0067
# Previous_Scores: 0.9832
# Tutoring_Sessions: 0.0027
# PI_High: 0.0000
# PI_Low: 0.0000
# AtR_High: 0.0000
# AtR_Low: 0.0000

# %%
h_rf.predict([[0, 0, 73, 3, 1, 0, 0, 0]])
# Out:
# c:\Users\plaza\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([65.10478649])

# %%
df[df['Exam_Score'] == 100]
# Out:
#       Hours_Studied  Attendance  Previous_Scores  Tutoring_Sessions  PI_High  \
# 9006             22          92               90                  7        0
# 9015             24          90               91                  7        1
# 9016             30         100               97                  8        0
# 9019             22          98               96                  8        0
# 9034             28          94               98                  8        0
# ...             ...         ...              ...                ...      ...
# 9957             21          99               93                  9        0
# 9961             25          95               91                  9        1
# 9969             21          99               92                  9        1
# 9973             28          99               95                  9        1
# 9999             27         100               99                  9        1
#
#       PI_Low  AtR_High  AtR_Low  Exam_Score
# 9006       0         1        0         100
# 9015       0         0        0         100
# 9016       0         1        0         100
# 9019       0         1        0         100
# 9034       0         0        0         100
# ...      ...       ...      ...         ...
# 9957       0         1        0         100
# 9961       0         0        0         100
# 9969       0         0        0         100
# 9973       0         1        0         100
# 9999       0         0        0         100
#
# [121 rows x 9 columns]

# %% [markdown]
# #### Guardamos el modelo con pickle

# %%
with open(r"C:\Users\plaza\Desktop\Documentos_Clase\ONLINE_DS_THEBRIDGE_Alejandro_Plaza\Proyecto_ML\models\random_forest.pkl", "wb") as f:
    pickle.dump(h_rf, f)
